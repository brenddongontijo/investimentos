# %%
import requests
import numpy
import pandas

# %% [markdown]
# # Coleta de dados

# %%
url = "https://www.fundsexplorer.com.br/ranking"
headers = {
    'User-Agent':
        'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:98.0) Gecko/20100101 Firefox/98.0'
}

# %%
response = requests.get(url=url, headers=headers)
if response.status_code == 200:
    data_frame = pandas.read_html(response.content, encoding='utf-8')[0]

# %% [markdown]
# # Tratamento de Dados

# %%
data_frame.sort_values('Códigodo fundo', inplace=True)

# %%
data_frame['Setor'].unique()
# Out:
# array(['Shoppings', 'Títulos e Val. Mob.', 'Lajes Corporativas',
#        'Logística', 'Híbrido', 'Outros', nan, 'Hospital', 'Residencial',
#        'Hotel'], dtype=object)

# %%
data_frame.columns
# Out:
# Index(['Códigodo fundo', 'Setor', 'Preço Atual', 'Liquidez Diária',
#        'Dividendo', 'DividendYield', 'DY (3M)Acumulado', 'DY (6M)Acumulado',
#        'DY (12M)Acumulado', 'DY (3M)Média', 'DY (6M)Média', 'DY (12M)Média',
#        'DY Ano', 'Variação Preço', 'Rentab.Período', 'Rentab.Acumulada',
#        'PatrimônioLíq.', 'VPA', 'P/VPA', 'DYPatrimonial',
#        'VariaçãoPatrimonial', 'Rentab. Patr.no Período',
#        'Rentab. Patr.Acumulada', 'VacânciaFísica', 'VacânciaFinanceira',
#        'QuantidadeAtivos'],
#       dtype='object')

# %%
data_frame
# Out:
#     Códigodo fundo                Setor Preço Atual  Liquidez Diária  \
# 198         ABCP11            Shoppings    R$ 72,02           1211.0
# 67          AFHI11  Títulos e Val. Mob.    R$ 99,30           6614.0
# 74          AFOF11  Títulos e Val. Mob.    R$ 89,49            198.0
# 226         AIEC11   Lajes Corporativas    R$ 73,93           7869.0
# 3           ALMI11   Lajes Corporativas   R$ 895,00              5.0
# ..             ...                  ...         ...              ...
# 80          XPML11            Shoppings    R$ 91,50          38195.0
# 101         XPPR11               Outros    R$ 44,89          24982.0
# 170         XPSF11               Outros     R$ 7,02          45394.0
# 2           XTED11   Lajes Corporativas     R$ 6,11          17185.0
# 38         YUFI11B          Residencial         NaN              NaN
#
#     Dividendo DividendYield DY (3M)Acumulado DY (6M)Acumulado  \
# 198   R$ 0,54         0,77%            2,47%            4,77%
# 67    R$ 1,40         1,37%            4,03%            7,86%
# 74    R$ 1,08         1,19%            3,53%            6,65%
# 226   R$ 0,80         1,05%            2,84%            6,07%
# 3     R$ 0,00         0,00%            0,00%            0,00%
# ..        ...           ...              ...              ...
# 80    R$ 0,68         0,70%            2,06%            4,30%
# 101   R$ 0,35         0,70%            2,30%            4,56%
# 170   R$ 0,07         0,99%            2,87%            5,56%
# 2     R$ 0,00         0,00%            0,00%            0,00%
# 38    R$ 0,60         0,00%            0,00%            0,00%
#
#     DY (12M)Acumulado DY (3M)Média  ...       PatrimônioLíq.          VPA  \
# 198             9,08%        0,82%  ...  R$ 1.120.247.855,81     R$ 91,79
# 67             14,40%        1,34%  ...    R$ 173.824.946,40     R$ 97,24
# 74              0,00%        1,18%  ...     R$ 69.242.339,50    R$ 100,18
# 226            10,82%        0,95%  ...    R$ 489.073.625,01    R$ 101,36
# 3               0,00%        0,00%  ...    R$ 249.632.973,43  R$ 2.245,37
# ..                ...          ...  ...                  ...          ...
# 80              7,63%        0,69%  ...  R$ 1.892.808.419,44    R$ 101,32
# 101             9,56%        0,77%  ...    R$ 565.410.376,25     R$ 77,28
# 170            10,70%        0,96%  ...    R$ 375.228.449,53      R$ 8,67
# 2               0,00%        0,00%  ...     R$ 27.305.951,24     R$ 13,89
# 38              0,00%        0,00%  ...     R$ 41.106.356,80    R$ 104,03
#
#      P/VPA DYPatrimonial VariaçãoPatrimonial Rentab. Patr.no Período  \
# 198   78.0         0,64%              -0,04%                   0,61%
# 67   102.0         1,39%               0,44%                   1,83%
# 74    89.0         1,08%              -2,09%                  -1,04%
# 226   73.0         0,71%               0,12%                   0,83%
# 3     40.0           NaN                 NaN                     NaN
# ..     ...           ...                 ...                     ...
# 80    90.0         0,67%               0,01%                   0,68%
# 101   58.0         0,58%              -1,54%                  -0,96%
# 170   81.0         0,80%             -90,09%                 -90,02%
# 2     44.0           NaN                 NaN                     NaN
# 38     NaN         0,58%              -0,28%                   0,29%
#
#     Rentab. Patr.Acumulada VacânciaFísica  VacânciaFinanceira QuantidadeAtivos
# 198                  3,33%          7,50%                 NaN                1
# 67                   3,20%            NaN                 NaN                0
# 74                   4,47%            NaN                 NaN                0
# 226                  3,49%          0,00%                 NaN                2
# 3                      NaN         64,05%                 NaN                1
# ..                     ...            ...                 ...              ...
# 80                   1,93%          3,90%                 NaN               16
# 101                 -2,87%         46,00%               0,00%                4
# 170                -89,78%            NaN                 NaN                0
# 2                      NaN          0,00%             100,00%                1
# 38                   2,72%            NaN                 NaN                0
#
# [282 rows x 26 columns]

# %%
data_frame[data_frame['Setor'].isna()]
# Out:
#     Códigodo fundo Setor Preço Atual  Liquidez Diária Dividendo DividendYield  \
# 250         BIME11   NaN     R$ 9,27          21218.0   R$ 0,16         1,68%
# 238         CXCI11   NaN    R$ 76,81            309.0   R$ 0,80         1,04%
# 281         ERPA11   NaN   R$ 127,00            541.0   R$ 0,27         0,21%
# 273         GTLG11   NaN    R$ 99,98           1070.0   R$ 0,70         0,70%
#
#     DY (3M)Acumulado DY (6M)Acumulado DY (12M)Acumulado DY (3M)Média  ...  \
# 250            4,67%            8,17%             0,00%        1,56%  ...
# 238            0,00%            0,00%             0,00%        0,00%  ...
# 281            0,00%            0,00%             0,00%        0,00%  ...
# 273            2,10%            4,21%             0,00%        0,70%  ...
#
#         PatrimônioLíq.        VPA  P/VPA DYPatrimonial VariaçãoPatrimonial  \
# 250   R$ 55.313.386,31    R$ 9,46   98.0         1,59%              -0,49%
# 238  R$ 200.991.074,86   R$ 97,68   79.0         0,72%              -0,07%
# 281   R$ 57.806.170,89  R$ 115,40  110.0         0,20%               0,24%
# 273  R$ 675.663.743,88   R$ 94,20  106.0         0,74%              -1,52%
#
#     Rentab. Patr.no Período Rentab. Patr.Acumulada VacânciaFísica  \
# 250                   1,09%                  4,17%            NaN
# 238                   0,65%                  0,96%            NaN
# 281                   0,43%                  0,43%            NaN
# 273                  -0,79%                 -0,28%            NaN
#
#      VacânciaFinanceira QuantidadeAtivos
# 250                 NaN                0
# 238                 NaN                0
# 281                 NaN                0
# 273                 NaN                0
#
# [4 rows x 26 columns]

# %% [markdown]
# # Definindo tipo de Dados Categóricos e Numéricos

# %%
categorical_columns = ['Códigodo fundo', 'Setor']
data_frame[categorical_columns] = data_frame[categorical_columns].astype('category')

# %%
float_columns = list(data_frame.iloc[:, 2:-1].columns)
data_frame[float_columns] = data_frame[float_columns].fillna(value=0)
data_frame[float_columns] = data_frame[float_columns].applymap(lambda x: str(x).replace('R$','').replace('.','').replace('%','').replace(',', '.'))
data_frame[float_columns] = data_frame[float_columns].astype('float')

# %%
data_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 282 entries, 198 to 38
# Data columns (total 26 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Códigodo fundo           282 non-null    category
#  1   Setor                    278 non-null    category
#  2   Preço Atual              282 non-null    float64
#  3   Liquidez Diária          282 non-null    float64
#  4   Dividendo                282 non-null    float64
#  5   DividendYield            282 non-null    float64
#  6   DY (3M)Acumulado         282 non-null    float64
#  7   DY (6M)Acumulado         282 non-null    float64
#  8   DY (12M)Acumulado        282 non-null    float64
#  9   DY (3M)Média             282 non-null    float64
#  10  DY (6M)Média             282 non-null    float64
#  11  DY (12M)Média            282 non-null    float64
#  12  DY Ano                   282 non-null    float64
#  13  Variação Preço           282 non-null    float64
#  14  Rentab.Período           282 non-null    float64
#  15  Rentab.Acumulada         282 non-null    float64
#  16  PatrimônioLíq.           282 non-null    float64
#  17  VPA                      282 non-null    float64
#  18  P/VPA                    282 non-null    float64
#  19  DYPatrimonial            282 non-null    float64
#  20  VariaçãoPatrimonial      282 non-null    float64
#  21  Rentab. Patr.no Período  282 non-null    float64
#  22  Rentab. Patr.Acumulada   282 non-null    float64
#  23  VacânciaFísica           282 non-null    float64
#  24  VacânciaFinanceira       282 non-null    float64
#  25  QuantidadeAtivos         282 non-null    int64
# dtypes: category(2), float64(23), int64(1)
# memory usage: 66.6 KB

# %% [markdown]
# # Realizando ajustes finais no dataframe

# %%
# checking infinity values
data_frame[numpy.isinf(data_frame[float_columns]).any(1)]
# Out:
# Empty DataFrame
# Columns: [Códigodo fundo, Setor, Preço Atual, Liquidez Diária, Dividendo, DividendYield, DY (3M)Acumulado, DY (6M)Acumulado, DY (12M)Acumulado, DY (3M)Média, DY (6M)Média, DY (12M)Média, DY Ano, Variação Preço, Rentab.Período, Rentab.Acumulada, PatrimônioLíq., VPA, P/VPA, DYPatrimonial, VariaçãoPatrimonial, Rentab. Patr.no Período, Rentab. Patr.Acumulada, VacânciaFísica, VacânciaFinanceira, QuantidadeAtivos]
# Index: []
#
# [0 rows x 26 columns]

# %%
# adjusting columns
data_frame['Liquidez Diária'] = data_frame['Liquidez Diária']/10
data_frame['P/VPA'] = data_frame['P/VPA']/1000

# %%
data_frame
# Out:
#     Códigodo fundo                Setor  Preço Atual  Liquidez Diária  \
# 198         ABCP11            Shoppings        72.02           1211.0
# 67          AFHI11  Títulos e Val. Mob.        99.30           6614.0
# 74          AFOF11  Títulos e Val. Mob.        89.49            198.0
# 226         AIEC11   Lajes Corporativas        73.93           7869.0
# 3           ALMI11   Lajes Corporativas       895.00              5.0
# ..             ...                  ...          ...              ...
# 80          XPML11            Shoppings        91.50          38195.0
# 101         XPPR11               Outros        44.89          24982.0
# 170         XPSF11               Outros         7.02          45394.0
# 2           XTED11   Lajes Corporativas         6.11          17185.0
# 38         YUFI11B          Residencial         0.00              0.0
#
#      Dividendo  DividendYield  DY (3M)Acumulado  DY (6M)Acumulado  \
# 198       0.54           0.77              2.47              4.77
# 67        1.40           1.37              4.03              7.86
# 74        1.08           1.19              3.53              6.65
# 226       0.80           1.05              2.84              6.07
# 3         0.00           0.00              0.00              0.00
# ..         ...            ...               ...               ...
# 80        0.68           0.70              2.06              4.30
# 101       0.35           0.70              2.30              4.56
# 170       0.07           0.99              2.87              5.56
# 2         0.00           0.00              0.00              0.00
# 38        0.60           0.00              0.00              0.00
#
#      DY (12M)Acumulado  DY (3M)Média  ...  PatrimônioLíq.      VPA  P/VPA  \
# 198               9.08          0.82  ...    1.120248e+09    91.79   0.78
# 67               14.40          1.34  ...    1.738249e+08    97.24   1.02
# 74                0.00          1.18  ...    6.924234e+07   100.18   0.89
# 226              10.82          0.95  ...    4.890736e+08   101.36   0.73
# 3                 0.00          0.00  ...    2.496330e+08  2245.37   0.40
# ..                 ...           ...  ...             ...      ...    ...
# 80                7.63          0.69  ...    1.892808e+09   101.32   0.90
# 101               9.56          0.77  ...    5.654104e+08    77.28   0.58
# 170              10.70          0.96  ...    3.752284e+08     8.67   0.81
# 2                 0.00          0.00  ...    2.730595e+07    13.89   0.44
# 38                0.00          0.00  ...    4.110636e+07   104.03   0.00
#
#      DYPatrimonial  VariaçãoPatrimonial  Rentab. Patr.no Período  \
# 198           0.64                -0.04                     0.61
# 67            1.39                 0.44                     1.83
# 74            1.08                -2.09                    -1.04
# 226           0.71                 0.12                     0.83
# 3             0.00                 0.00                     0.00
# ..             ...                  ...                      ...
# 80            0.67                 0.01                     0.68
# 101           0.58                -1.54                    -0.96
# 170           0.80               -90.09                   -90.02
# 2             0.00                 0.00                     0.00
# 38            0.58                -0.28                     0.29
#
#      Rentab. Patr.Acumulada  VacânciaFísica  VacânciaFinanceira  \
# 198                    3.33            7.50                 0.0
# 67                     3.20            0.00                 0.0
# 74                     4.47            0.00                 0.0
# 226                    3.49            0.00                 0.0
# 3                      0.00           64.05                 0.0
# ..                      ...             ...                 ...
# 80                     1.93            3.90                 0.0
# 101                   -2.87           46.00                 0.0
# 170                  -89.78            0.00                 0.0
# 2                      0.00            0.00               100.0
# 38                     2.72            0.00                 0.0
#
#      QuantidadeAtivos
# 198                 1
# 67                  0
# 74                  0
# 226                 2
# 3                   1
# ..                ...
# 80                 16
# 101                 4
# 170                 0
# 2                   1
# 38                  0
#
# [282 rows x 26 columns]

# %%
data_frame.describe()
# Out:
#         Preço Atual  Liquidez Diária   Dividendo  DividendYield  \
# count    282.000000       282.000000  282.000000     282.000000
# mean     475.420106     16572.003546    1.233865       0.903546
# std     4751.727317     50963.706744    2.516132       0.481225
# min        0.000000         0.000000    0.000000       0.000000
# 25%       62.087500       173.250000    0.472500       0.672500
# 50%       86.855000      2175.000000    0.750000       0.920000
# 75%      100.000000     11656.750000    1.245000       1.217500
# max    76000.000000    436320.000000   26.660000       2.900000
#
#        DY (3M)Acumulado  DY (6M)Acumulado  DY (12M)Acumulado  DY (3M)Média  \
# count        282.000000        282.000000         282.000000    282.000000
# mean           2.554255          4.701950           7.772305      0.851809
# std            1.349679          2.564124           5.124257      0.450112
# min            0.000000          0.000000           0.000000      0.000000
# 25%            1.920000          3.515000           3.662500      0.642500
# 50%            2.580000          4.940000           8.885000      0.860000
# 75%            3.512500          6.577500          11.177500      1.167500
# max            7.330000          9.890000          18.350000      2.440000
#
#        DY (6M)Média  DY (12M)Média  ...  PatrimônioLíq.           VPA  \
# count    282.000000     282.000000  ...    2.820000e+02    282.000000
# mean       0.783617       0.647695  ...    5.235475e+08    516.832624
# std        0.427164       0.426972  ...    7.816656e+08   4544.565996
# min        0.000000       0.000000  ...   -1.025113e+07    -13.520000
# 25%        0.590000       0.305000  ...    1.015943e+08     87.502500
# 50%        0.820000       0.740000  ...    2.375445e+08     98.085000
# 75%        1.097500       0.930000  ...    5.824695e+08    108.550000
# max        1.650000       1.530000  ...    6.938900e+09  70498.040000
#
#             P/VPA  DYPatrimonial  VariaçãoPatrimonial  \
# count  282.000000     282.000000           282.000000
# mean     0.846986       0.748511            -0.786950
# std      0.673233       0.474055             7.763505
# min     -0.480000       0.000000           -90.090000
# 25%      0.702500       0.492500            -0.397500
# 50%      0.855000       0.710000             0.000000
# 75%      0.980000       1.110000             0.070000
# max     11.210000       1.930000            19.220000
#
#        Rentab. Patr.no Período  Rentab. Patr.Acumulada  VacânciaFísica  \
# count               282.000000              282.000000      282.000000
# mean                 -0.044362                1.084078        6.513582
# std                   7.839990               11.692324       16.657419
# min                 -90.020000              -98.910000        0.000000
# 25%                   0.000000                0.412500        0.000000
# 50%                   0.530000                2.195000        0.000000
# 75%                   1.040000                4.192500        2.550000
# max                  20.560000               29.920000      100.000000
#
#        VacânciaFinanceira  QuantidadeAtivos
# count          282.000000        282.000000
# mean             1.186915          3.092199
# std              7.502954          7.686843
# min              0.000000          0.000000
# 25%              0.000000          0.000000
# 50%              0.000000          0.000000
# 75%              0.000000          3.000000
# max            100.000000         72.000000
#
# [8 rows x 24 columns]

# %%
indicadores = [
    'Setor',
    'DY (12M)Acumulado',
    'VacânciaFísica',
    'P/VPA',
    'QuantidadeAtivos',
    'Liquidez Diária',
    'PatrimônioLíq.',
]

# %%
df_aux = data_frame[indicadores]

# %%
df_aux
# Out:
#                    Setor  DY (12M)Acumulado  VacânciaFísica  P/VPA  \
# 198            Shoppings               9.08            7.50   0.78
# 67   Títulos e Val. Mob.              14.40            0.00   1.02
# 74   Títulos e Val. Mob.               0.00            0.00   0.89
# 226   Lajes Corporativas              10.82            0.00   0.73
# 3     Lajes Corporativas               0.00           64.05   0.40
# ..                   ...                ...             ...    ...
# 80             Shoppings               7.63            3.90   0.90
# 101               Outros               9.56           46.00   0.58
# 170               Outros              10.70            0.00   0.81
# 2     Lajes Corporativas               0.00            0.00   0.44
# 38           Residencial               0.00            0.00   0.00
#
#      QuantidadeAtivos  Liquidez Diária  PatrimônioLíq.
# 198                 1           1211.0    1.120248e+09
# 67                  0           6614.0    1.738249e+08
# 74                  0            198.0    6.924234e+07
# 226                 2           7869.0    4.890736e+08
# 3                   1              5.0    2.496330e+08
# ..                ...              ...             ...
# 80                 16          38195.0    1.892808e+09
# 101                 4          24982.0    5.654104e+08
# 170                 0          45394.0    3.752284e+08
# 2                   1          17185.0    2.730595e+07
# 38                  0              0.0    4.110636e+07
#
# [282 rows x 7 columns]

# %%
media_setor = df_aux.groupby('Setor').agg(['mean', 'std'])

# %%
setores = [
    "Hospital",
    "Hotel",
    "Híbrido",
    "Lajes Corporativas",
    "Logística",
    "Outros",
    "Residencial",
    "Shoppings",
    "Títulos e Val. Mob.",
]

# %%
media_setor
# Out:
#                     DY (12M)Acumulado           VacânciaFísica             \
#                                  mean       std           mean        std
# Setor
# Hospital                     8.563333  1.468650       0.000000   0.000000
# Hotel                        6.796667  3.120342      43.300000  37.498933
# Híbrido                      7.062083  5.071284       2.220833   5.098410
# Lajes Corporativas           6.781951  4.413156      26.366341  29.492080
# Logística                    8.159545  2.877556       7.263636  17.558000
# Outros                       8.989189  5.198407       2.469459   8.223041
# Residencial                  1.738000  3.705305       3.040000   8.802424
# Shoppings                    5.841364  2.923164      10.806364  12.131324
# Títulos e Val. Mob.          9.463804  5.585433       0.000000   0.000000
#
#                         P/VPA           QuantidadeAtivos             \
#                          mean       std             mean        std
# Setor
# Hospital             0.773333  0.090185         1.000000   0.000000
# Hotel                0.823333  0.256970         9.333333  12.096832
# Híbrido              0.771667  0.320401         3.687500   6.088553
# Lajes Corporativas   0.699756  0.271648         4.097561  10.270844
# Logística            0.832273  0.129943         7.409091   5.586200
# Outros               0.772162  0.257252         6.027027  14.078128
# Residencial          0.693000  0.614438         0.600000   1.349897
# Shoppings            0.692727  0.220566         4.454545   5.369466
# Títulos e Val. Mob.  1.036413  1.082817         0.065217   0.625543
#
#                     Liquidez Diária               PatrimônioLíq.
#                                mean           std           mean           std
# Setor
# Hospital                1154.000000   1499.832991   2.724733e+08  2.397485e+08
# Hotel                   1102.333333   1008.550610   2.164871e+08  1.234496e+08
# Híbrido                15887.250000  62821.200500   5.130893e+08  8.047850e+08
# Lajes Corporativas      3624.609756   5462.134399   3.668078e+08  4.120159e+08
# Logística              12902.136364  23778.806519   9.082549e+08  9.560699e+08
# Outros                 15578.162162  24814.564652   4.531304e+08  5.196859e+08
# Residencial             1647.800000   3196.337307   1.316364e+08  1.298815e+08
# Shoppings               5726.045455  10368.081622   6.742987e+08  6.714342e+08
# Títulos e Val. Mob.    29668.597826  72379.237307   5.719344e+08  9.835954e+08

# %% [markdown]
# # Mostrando Oportunidades

# %%
def oportunidade_media_setor(dataframe, label_setor='Setor', setor=None):
    media_setor = df_aux.groupby('Setor').agg(['mean', 'std'])
    df_setor = dataframe[dataframe[label_setor].isin([setor])]
    filter = None
    
    if setor == "Hospital":
        filter = \
            (df_setor['Liquidez Diária'] > 1)
    elif setor == "Hotel":
        filter = \
            (df_setor['QuantidadeAtivos'] > 3) & \
            (df_setor['Liquidez Diária'] > 1000) & \
            (df_setor['P/VPA'] < 1.0) & \
            (df_setor['DY (12M)Acumulado'] > media_setor.loc[setor, ('DY (12M)Acumulado', 'mean')])
    elif setor == "Híbrido":
        filter = \
            (df_setor['QuantidadeAtivos'] > 0) & \
            (df_setor['Liquidez Diária'] > 5000) & \
            (df_setor['P/VPA'] < 1.0) & \
            (df_setor['DY (12M)Acumulado'] > media_setor.loc[setor, ('DY (12M)Acumulado', 'mean')])
    elif setor == "Lajes Corporativas":
        filter = \
            (df_setor['QuantidadeAtivos'] > 0) & \
            (df_setor['Liquidez Diária'] > 5000) & \
            (df_setor['P/VPA'] < 1.0) & \
            (df_setor['DY (12M)Acumulado'] > media_setor.loc[setor, ('DY (12M)Acumulado', 'mean')])
    elif setor == "Logística":
        filter = \
            (df_setor['QuantidadeAtivos'] > 0) & \
            (df_setor['Liquidez Diária'] > 5000) & \
            (df_setor['P/VPA'] < 1.0) & \
            (df_setor['DY (12M)Acumulado'] > media_setor.loc[setor, ('DY (12M)Acumulado', 'mean')])
    elif setor == "Outros":
        filter = \
            (df_setor['QuantidadeAtivos'] > 0) & \
            (df_setor['Liquidez Diária'] > 5000) & \
            (df_setor['P/VPA'] < 1.0) & \
            (df_setor['DY (12M)Acumulado'] > media_setor.loc[setor, ('DY (12M)Acumulado', 'mean')])
    elif setor == "Residencial":
        filter = \
            (df_setor['QuantidadeAtivos'] > 0) & \
            (df_setor['Liquidez Diária'] > 5000) & \
            (df_setor['P/VPA'] < 1.0) & \
            (df_setor['DY (12M)Acumulado'] > media_setor.loc[setor, ('DY (12M)Acumulado', 'mean')])
    elif setor == "Shoppings":
        filter = \
            (df_setor['QuantidadeAtivos'] > 0) & \
            (df_setor['Liquidez Diária'] > 5000) & \
            (df_setor['P/VPA'] < 1.0) & \
            (df_setor['DY (12M)Acumulado'] > media_setor.loc[setor, ('DY (12M)Acumulado', 'mean')])
    elif setor == "Títulos e Val. Mob.":
        filter = \
            (df_setor['QuantidadeAtivos'] > 0) & \
            (df_setor['Liquidez Diária'] > 5000) & \
            (df_setor['P/VPA'] < 1.0) & \
            (df_setor['DY (12M)Acumulado'] > media_setor.loc[setor, ('DY (12M)Acumulado', 'mean')])
    
    return df_setor[filter]

# %%
for setor in setores:
    oportunidade = oportunidade_media_setor(data_frame, setor=setor)

    if not oportunidade.empty:
        print(setor)
        oportunidade.sort_values('DY (12M)Acumulado', ascending=False, inplace=True)
        display(oportunidade)
        print('\n')
# Out:
# Hospital
#    Códigodo fundo     Setor  Preço Atual  Liquidez Diária  Dividendo  \
# 7          NSLU11  Hospital        140.9           2877.0       1.54
# 26         HCRI11  Hospital        201.4            444.0       2.49
# 34         NVHO11  Hospital         10.9            141.0       0.08
#
#     DividendYield  DY (3M)Acumulado  DY (6M)Acumulado  DY (12M)Acumulado  \
# 7            0.76              2.26              4.94               9.49
# 26           0.88              2.36              4.77               9.33
# 34           0.67              1.97              3.50               6.87
#
#     DY (3M)Média  ...  PatrimônioLíq.     VPA  P/VPA  DYPatrimonial  \
# 7           0.75  ...    2.380284e+08  207.92   0.68            0.0
# 26          0.79  ...    5.181019e+07  259.05   0.78            0.0
# 34          0.66  ...    5.275812e+08   12.71   0.86            0.0
#
#     VariaçãoPatrimonial  Rentab. Patr.no Período  Rentab. Patr.Acumulada  \
# 7                   0.0                      0.0                     0.0
# 26                  0.0                      0.0                     0.0
# 34                  0.0                      0.0                     0.0
#
#     VacânciaFísica  VacânciaFinanceira  QuantidadeAtivos
# 7              0.0                 0.0                 1
# 26             0.0                 0.0                 1
# 34             0.0                 0.0                 1
#
# [3 rows x 26 columns]
# Híbrido
#     Códigodo fundo    Setor  Preço Atual  Liquidez Diária  Dividendo  \
# 126         SARE11  Híbrido        69.25          10892.0       0.70
# 127         PATL11  Híbrido        71.60          14989.0       0.58
# 275         RECT11  Híbrido        56.76          11750.0       0.50
# 251         BRCR11  Híbrido        59.49          34115.0       0.47
# 183         HGRU11  Híbrido       117.56          27885.0       1.20
# 177         JSRE11  Híbrido        76.99          19373.0       0.49
#
#      DividendYield  DY (3M)Acumulado  DY (6M)Acumulado  DY (12M)Acumulado  \
# 126           1.04              2.68              5.32              10.16
# 127           0.75              2.25              4.54               9.31
# 275           0.88              2.54              4.79               9.11
# 251           0.79              2.22              4.38               8.35
# 183           1.01              2.41              4.48               8.29
# 177           0.65              1.91              3.93               7.96
#
#      DY (3M)Média  ...  PatrimônioLíq.     VPA  P/VPA  DYPatrimonial  \
# 126          0.89  ...    9.112110e+08   98.68   0.70           0.63
# 127          0.75  ...    4.892685e+08   98.02   0.73           0.59
# 275          0.85  ...    7.891244e+08   96.48   0.59           0.52
# 251          0.74  ...    2.703973e+09  101.51   0.59           0.46
# 183          0.80  ...    2.191214e+09  119.05   0.99           0.69
# 177          0.64  ...    2.359889e+09  113.63   0.68           0.43
#
#      VariaçãoPatrimonial  Rentab. Patr.no Período  Rentab. Patr.Acumulada  \
# 126                -0.19                     0.44                    2.64
# 127                -0.02                     0.58                    2.98
# 275                -0.35                     0.17                    1.39
# 251                -3.16                    -2.72                   -2.38
# 183                 0.17                     0.86                    3.66
# 177                -0.03                     0.40                    1.87
#
#      VacânciaFísica  VacânciaFinanceira  QuantidadeAtivos
# 126             6.2                 0.0                 3
# 127             0.0                 0.0                 4
# 275            15.1                 0.0                 8
# 251            21.0                25.8                15
# 183             0.0                 0.0                17
# 177            14.8                13.4                 5
#
# [6 rows x 26 columns]
# Lajes Corporativas
#     Códigodo fundo               Setor  Preço Atual  Liquidez Diária  \
# 224         BBPO11  Lajes Corporativas        79.97          17350.0
# 226         AIEC11  Lajes Corporativas        73.93           7869.0
# 208         XPCM11  Lajes Corporativas        14.25           5973.0
# 200         VINO11  Lajes Corporativas        44.31          18197.0
# 119         HGRE11  Lajes Corporativas       128.58          11778.0
# 158         PVBI11  Lajes Corporativas        89.05          18392.0
#
#      Dividendo  DividendYield  DY (3M)Acumulado  DY (6M)Acumulado  \
# 224       0.89           1.11              3.21              6.14
# 226       0.80           1.05              2.84              6.07
# 208       0.16           1.07              3.19              5.95
# 200       0.34           0.77              2.13              4.22
# 119       0.78           0.60              1.81              3.42
# 158       0.56           0.61              1.79              3.68
#
#      DY (12M)Acumulado  DY (3M)Média  ...  PatrimônioLíq.     VPA  P/VPA  \
# 224              11.54          1.07  ...    1.512932e+09   95.04   0.84
# 226              10.82          0.95  ...    4.890736e+08  101.36   0.73
# 208              10.37          1.06  ...    1.291121e+08   53.47   0.27
# 200               9.80          0.71  ...    8.980584e+08   54.21   0.82
# 119               8.09          0.60  ...    1.924602e+09  162.86   0.79
# 158               7.41          0.60  ...    9.952759e+08   99.14   0.90
#
#      DYPatrimonial  VariaçãoPatrimonial  Rentab. Patr.no Período  \
# 224           0.94                -0.90                     0.03
# 226           0.71                 0.12                     0.83
# 208           0.34                -0.57                    -0.24
# 200           0.63                -0.71                    -0.09
# 119           0.48                -1.08                    -0.61
# 158           0.56                -0.14                     0.42
#
#      Rentab. Patr.Acumulada  VacânciaFísica  VacânciaFinanceira  \
# 224                    3.87            0.00                0.00
# 226                    3.49            0.00                0.00
# 208                   -0.69          100.00                0.00
# 200                    0.91            4.20                0.00
# 119                    0.46           27.13               29.17
# 158                    0.99            0.10                0.00
#
#      QuantidadeAtivos
# 224                64
# 226                 2
# 208                 1
# 200                 9
# 119                21
# 158                 4
#
# [6 rows x 26 columns]
# Logística
#     Códigodo fundo      Setor  Preço Atual  Liquidez Diária  Dividendo  \
# 262         BLMG11  Logística        77.51           7056.0       0.80
# 121         SDIL11  Logística        89.80           8625.0       0.76
# 244         GGRC11  Logística       106.59          13927.0       0.94
# 159         LVBI11  Logística        98.19          13620.0       0.74
# 78          BTLG11  Logística        97.30          36720.0       0.72
#
#      DividendYield  DY (3M)Acumulado  DY (6M)Acumulado  DY (12M)Acumulado  \
# 262           1.03              2.94              5.63              11.24
# 121           0.87              2.53              5.09               9.87
# 244           0.86              2.53              4.91               9.16
# 159           0.75              2.22              4.35               8.38
# 78            0.71              2.11              4.19               8.22
#
#      DY (3M)Média  ...  PatrimônioLíq.     VPA  P/VPA  DYPatrimonial  \
# 262          0.98  ...    3.609182e+08   94.71   0.82           0.84
# 121          0.84  ...    6.387499e+08   99.88   0.90           0.76
# 244          0.84  ...    1.012027e+09  130.44   0.82           0.71
# 159          0.74  ...    1.350473e+09  114.69   0.86           0.65
# 78           0.70  ...    1.504876e+09   98.82   0.98           0.73
#
#      VariaçãoPatrimonial  Rentab. Patr.no Período  Rentab. Patr.Acumulada  \
# 262                -2.04                    -1.21                   -3.03
# 121                -0.69                     0.06                    6.46
# 244                -0.06                     0.65                    2.17
# 159                -0.08                     0.57                    1.19
# 78                 -0.22                     0.51                    1.24
#
#      VacânciaFísica  VacânciaFinanceira  QuantidadeAtivos
# 262             0.0                 0.0                 4
# 121             2.6                 0.0                 5
# 244             0.0                 0.0                15
# 159             0.5                 0.0                10
# 78              0.0                 2.0                16
#
# [5 rows x 26 columns]
# Outros
#     Códigodo fundo   Setor  Preço Atual  Liquidez Diária  Dividendo  \
# 87          BTAL11  Outros        92.20          10248.0       0.83
# 101         XPPR11  Outros        44.89          24982.0       0.35
#
#      DividendYield  DY (3M)Acumulado  DY (6M)Acumulado  DY (12M)Acumulado  \
# 87            0.84              2.52              5.07               9.81
# 101           0.70              2.30              4.56               9.56
#
#      DY (3M)Média  ...  PatrimônioLíq.     VPA  P/VPA  DYPatrimonial  \
# 87           0.84  ...    6.202946e+08  103.68   0.89           0.80
# 101          0.77  ...    5.654104e+08   77.28   0.58           0.58
#
#      VariaçãoPatrimonial  Rentab. Patr.no Período  Rentab. Patr.Acumulada  \
# 87                  0.51                     1.32                    2.10
# 101                -1.54                    -0.96                   -2.87
#
#      VacânciaFísica  VacânciaFinanceira  QuantidadeAtivos
# 87              0.0                 0.0                 7
# 101            46.0                 0.0                 4
#
# [2 rows x 26 columns]
# Shoppings
#     Códigodo fundo      Setor  Preço Atual  Liquidez Diária  Dividendo  \
# 205         HSML11  Shoppings        76.46          30445.0       0.65
# 168         MALL11  Shoppings       100.49           8616.0       0.72
# 122         VISC11  Shoppings        99.90          18161.0       0.70
# 80          XPML11  Shoppings        91.50          38195.0       0.68
#
#      DividendYield  DY (3M)Acumulado  DY (6M)Acumulado  DY (12M)Acumulado  \
# 205           0.83              2.35              4.59               8.49
# 168           0.71              2.13              4.32               8.10
# 122           0.69              2.06              4.11               7.71
# 80            0.70              2.06              4.30               7.63
#
#      DY (3M)Média  ...  PatrimônioLíq.     VPA  P/VPA  DYPatrimonial  \
# 205          0.78  ...    1.470238e+09   93.17   0.82           0.67
# 168          0.71  ...    8.191508e+08  108.35   0.93           0.66
# 122          0.69  ...    2.037764e+09  115.15   0.87           0.61
# 80           0.69  ...    1.892808e+09  101.32   0.90           0.67
#
#      VariaçãoPatrimonial  Rentab. Patr.no Período  Rentab. Patr.Acumulada  \
# 205                -0.63                     0.03                    1.62
# 168                -0.46                     0.20                    1.11
# 122                -0.43                     0.18                    2.16
# 80                  0.01                     0.68                    1.93
#
#      VacânciaFísica  VacânciaFinanceira  QuantidadeAtivos
# 205             4.5                 0.0                 5
# 168             4.0                 0.0                 8
# 122             8.3                 0.0                15
# 80              3.9                 0.0                16
#
# [4 rows x 26 columns]
# Títulos e Val. Mob.
#     Códigodo fundo                Setor  Preço Atual  Liquidez Diária  \
# 138         VIUR11  Títulos e Val. Mob.         7.15          11377.0
#
#      Dividendo  DividendYield  DY (3M)Acumulado  DY (6M)Acumulado  \
# 138       0.07            1.0              2.98              5.81
#
#      DY (12M)Acumulado  DY (3M)Média  ...  PatrimônioLíq.   VPA  P/VPA  \
# 138              10.72          0.99  ...    2.562974e+08  9.51   0.75
#
#      DYPatrimonial  VariaçãoPatrimonial  Rentab. Patr.no Período  \
# 138           0.76               -90.08                    -90.0
#
#      Rentab. Patr.Acumulada  VacânciaFísica  VacânciaFinanceira  \
# 138                  -89.78             0.0                 0.0
#
#      QuantidadeAtivos
# 138                 6
#
# [1 rows x 26 columns]
